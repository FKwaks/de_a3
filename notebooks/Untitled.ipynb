# %%
import pandas as pd
holdout_engine = 50
data = pd.read_parquet('feature_store_RUL_features.parquet')
    
RUL_df = data.loc[data.engine_id != holdout_engine].iloc[:,2:].copy()
    
labels = RUL_df['RUL']
features = RUL_df.iloc[:,1:]

#X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size = 0.2, random_state = 42)

# %%
data.head()
# Out:
#    engine_id  cycle  RUL  setting1  setting2  setting3      s1      s2  \
# 0          1      1  192   -0.0007   -0.0004     100.0  518.67  641.82
# 1          1      2  191    0.0019   -0.0003     100.0  518.67  642.15
# 2          1      3  190   -0.0043    0.0003     100.0  518.67  642.35
# 3          1      4  189    0.0007    0.0000     100.0  518.67  642.35
# 4          1      5  188   -0.0019   -0.0002     100.0  518.67  642.37
#
#         s3       s4  ...  delta_s17  max_s18  min_s18  delta_s18  max_s19  \
# 0  1589.70  1400.60  ...        0.0     2388     2388        0.0    100.0
# 1  1591.82  1403.14  ...        0.0     2388     2388        0.0    100.0
# 2  1587.99  1404.20  ...       -2.0     2388     2388        0.0    100.0
# 3  1582.79  1401.87  ...        2.0     2388     2388        0.0    100.0
# 4  1582.85  1406.22  ...        1.0     2388     2388        0.0    100.0
#
#    min_s19  delta_s19  max_s20  min_s20  delta_s20
# 0    100.0        0.0    39.06    39.06       0.00
# 1    100.0        0.0    39.06    39.00      -0.06
# 2    100.0        0.0    39.06    38.95      -0.05
# 3    100.0        0.0    39.06    38.88      -0.07
# 4    100.0        0.0    39.06    38.88       0.02
#
# [5 rows x 96 columns]
